# %% [markdown]
# <a href="https://colab.research.google.com/github/Promilasharan/Predicting-Binding-Affinity-of-Drug-Compounds-for-BACE1/blob/main/BACE1_Data_Preprocessing_Part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.8-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.26.16)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.27.1)
# Collecting requests-cache~=0.7.0 (from chembl_webresource_client)
#   Downloading requests_cache-0.7.5-py3-none-any.whl (39 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4)
# Collecting attrs<22.0,>=21.2 (from requests-cache~=0.7.0->chembl_webresource_client)
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: itsdangerous>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.1.2)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0)
# Collecting url-normalize<2.0,>=1.4 (from requests-cache~=0.7.0->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)
# Installing collected packages: url-normalize, attrs, requests-cache, chembl_webresource_client
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# Successfully installed attrs-21.4.0 chembl_webresource_client-0.10.8 requests-cache-0.7.5 url-normalize-1.4.3

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for BACE**

# %%
target = new_client.target
target_query = target.search('BACE')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references            organism  \
# 0                                                 []        Homo sapiens
# 1                                                 []   Rattus norvegicus
# 2                                                 []        Mus musculus
# 3  [{'xref_id': 'Beta-secretase_1', 'xref_name': ...        Homo sapiens
# 4  [{'xref_id': 'P56818', 'xref_name': None, 'xre...        Mus musculus
# 5                                                 []   Rattus norvegicus
# 6                                                 []  Cricetulus griseus
# 7  [{'xref_id': 'Q9Y5Z0', 'xref_name': None, 'xre...        Homo sapiens
#
#                pref_name  score  species_group_flag target_chembl_id  \
# 0  Beta-secretase (BACE)   15.0               False    CHEMBL2111390
# 1       Beta-secretase 2   12.0               False    CHEMBL2331066
# 2       Beta-secretase 2   12.0               False    CHEMBL3638357
# 3       Beta-secretase 1   11.0               False       CHEMBL4822
# 4       Beta-secretase 1   11.0               False       CHEMBL4593
# 5       Beta-secretase 1   11.0               False    CHEMBL3259473
# 6       Beta-secretase 1   11.0               False    CHEMBL3297642
# 7       Beta secretase 2   10.0               False       CHEMBL2525
#
#                                    target_components     target_type  tax_id
# 0  [{'accession': 'Q9Y5Z0', 'component_descriptio...  PROTEIN FAMILY    9606
# 1  [{'accession': 'Q6IE75', 'component_descriptio...  SINGLE PROTEIN   10116
# 2  [{'accession': 'Q9JL18', 'component_descriptio...  SINGLE PROTEIN   10090
# 3  [{'accession': 'P56817', 'component_descriptio...  SINGLE PROTEIN    9606
# 4  [{'accession': 'P56818', 'component_descriptio...  SINGLE PROTEIN   10090
# 5  [{'accession': 'P56819', 'component_descriptio...  SINGLE PROTEIN   10116
# 6  [{'accession': 'G3IAK4', 'component_descriptio...  SINGLE PROTEIN   10029
# 7  [{'accession': 'Q9Y5Z0', 'component_descriptio...  SINGLE PROTEIN    9606

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Bace1* (4th entry)**

# %% [markdown]
# We will assign the fourth entry (which corresponds to the target protein, *Human BACE1*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[3]
selected_target
# Out:
# 'CHEMBL4822'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human BACE1* (CHEMBL4822) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                              action_type activity_comment  \
# 0                                                   None             None
# 1                                                   None             None
# 2                                                   None             None
# 3                                                   None             None
# 4                                                   None             None
# ...                                                  ...              ...
# 10614  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 10615  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 10616  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 10617  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 10618  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#        activity_id                                activity_properties  \
# 0            78857                                                 []
# 1           391560                                                 []
# 2           391983                                                 []
# 3           395858                                                 []
# 4           395859                                                 []
# ...            ...                                                ...
# 10614     24890923  [{'comments': None, 'relation': '=', 'result_f...
# 10615     24890924  [{'comments': None, 'relation': '=', 'result_f...
# 10616     24890925  [{'comments': None, 'relation': '=', 'result_f...
# 10617     24963344                                                 []
# 10618     24963345                                                 []
#
#       assay_chembl_id                                  assay_description  \
# 0        CHEMBL653511  Inhibitory activity against Beta-secretase 1 w...
# 1        CHEMBL653332  Compound was tested for its inhibitory activit...
# 2        CHEMBL653512               Inhibition of human Beta-secretase 1
# 3        CHEMBL653512               Inhibition of human Beta-secretase 1
# 4        CHEMBL653512               Inhibition of human Beta-secretase 1
# ...               ...                                                ...
# 10614   CHEMBL5158468  Inhibition of BACE1 (unknown origin) using Mca...
# 10615   CHEMBL5158468  Inhibition of BACE1 (unknown origin) using Mca...
# 10616   CHEMBL5158468  Inhibition of BACE1 (unknown origin) using Mca...
# 10617   CHEMBL5216426  Inhibition of BACE1 (unknown origin) using A-b...
# 10618   CHEMBL5216426  Inhibition of BACE1 (unknown origin) using A-b...
#
#       assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0              B                    None                   None  BAO_0000190
# 1              B                    None                   None  BAO_0000190
# 2              B                    None                   None  BAO_0000190
# 3              B                    None                   None  BAO_0000190
# 4              B                    None                   None  BAO_0000190
# ...          ...                     ...                    ...          ...
# 10614          B                    None                   None  BAO_0000190
# 10615          B                    None                   None  BAO_0000190
# 10616          B                    None                   None  BAO_0000190
# 10617          B                    None                   None  BAO_0000190
# 10618          B                    None                   None  BAO_0000190
#
#        ... target_organism  target_pref_name target_tax_id text_value  toid  \
# 0      ...    Homo sapiens  Beta-secretase 1          9606       None  None
# 1      ...    Homo sapiens  Beta-secretase 1          9606       None  None
# 2      ...    Homo sapiens  Beta-secretase 1          9606       None  None
# 3      ...    Homo sapiens  Beta-secretase 1          9606       None  None
# 4      ...    Homo sapiens  Beta-secretase 1          9606       None  None
# ...    ...             ...               ...           ...        ...   ...
# 10614  ...    Homo sapiens  Beta-secretase 1          9606       None  None
# 10615  ...    Homo sapiens  Beta-secretase 1          9606       None  None
# 10616  ...    Homo sapiens  Beta-secretase 1          9606       None  None
# 10617  ...    Homo sapiens  Beta-secretase 1          9606       None  None
# 10618  ...    Homo sapiens  Beta-secretase 1          9606       None  None
#
#        type units    uo_units upper_value   value
# 0      IC50    nM  UO_0000065        None   413.0
# 1      IC50    uM  UO_0000065        None   0.002
# 2      IC50    uM  UO_0000065        None    0.46
# 3      IC50    uM  UO_0000065        None     9.0
# 4      IC50    uM  UO_0000065        None     5.6
# ...     ...   ...         ...         ...     ...
# 10614  IC50    nM  UO_0000065        None   775.0
# 10615  IC50    nM  UO_0000065        None  1031.0
# 10616  IC50    nM  UO_0000065        None   828.0
# 10617  IC50    nM  UO_0000065        None    15.1
# 10618  IC50    nM  UO_0000065        None    15.4
#
# [10619 rows x 46 columns]

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('BACE_1_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-9-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                              action_type activity_comment  \
# 0                                                   None             None
# 1                                                   None             None
# 2                                                   None             None
# 3                                                   None             None
# 4                                                   None             None
# ...                                                  ...              ...
# 10614  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 10615  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 10616  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 10617  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 10618  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#        activity_id                                activity_properties  \
# 0            78857                                                 []
# 1           391560                                                 []
# 2           391983                                                 []
# 3           395858                                                 []
# 4           395859                                                 []
# ...            ...                                                ...
# 10614     24890923  [{'comments': None, 'relation': '=', 'result_f...
# 10615     24890924  [{'comments': None, 'relation': '=', 'result_f...
# 10616     24890925  [{'comments': None, 'relation': '=', 'result_f...
# 10617     24963344                                                 []
# 10618     24963345                                                 []
#
#       assay_chembl_id                                  assay_description  \
# 0        CHEMBL653511  Inhibitory activity against Beta-secretase 1 w...
# 1        CHEMBL653332  Compound was tested for its inhibitory activit...
# 2        CHEMBL653512               Inhibition of human Beta-secretase 1
# 3        CHEMBL653512               Inhibition of human Beta-secretase 1
# 4        CHEMBL653512               Inhibition of human Beta-secretase 1
# ...               ...                                                ...
# 10614   CHEMBL5158468  Inhibition of BACE1 (unknown origin) using Mca...
# 10615   CHEMBL5158468  Inhibition of BACE1 (unknown origin) using Mca...
# 10616   CHEMBL5158468  Inhibition of BACE1 (unknown origin) using Mca...
# 10617   CHEMBL5216426  Inhibition of BACE1 (unknown origin) using A-b...
# 10618   CHEMBL5216426  Inhibition of BACE1 (unknown origin) using A-b...
#
#       assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0              B                    None                   None  BAO_0000190
# 1              B                    None                   None  BAO_0000190
# 2              B                    None                   None  BAO_0000190
# 3              B                    None                   None  BAO_0000190
# 4              B                    None                   None  BAO_0000190
# ...          ...                     ...                    ...          ...
# 10614          B                    None                   None  BAO_0000190
# 10615          B                    None                   None  BAO_0000190
# 10616          B                    None                   None  BAO_0000190
# 10617          B                    None                   None  BAO_0000190
# 10618          B                    None                   None  BAO_0000190
#
#        ... target_organism  target_pref_name target_tax_id text_value  toid  \
# 0      ...    Homo sapiens  Beta-secretase 1          9606       None  None
# 1      ...    Homo sapiens  Beta-secretase 1          9606       None  None
# 2      ...    Homo sapiens  Beta-secretase 1          9606       None  None
# 3      ...    Homo sapiens  Beta-secretase 1          9606       None  None
# 4      ...    Homo sapiens  Beta-secretase 1          9606       None  None
# ...    ...             ...               ...           ...        ...   ...
# 10614  ...    Homo sapiens  Beta-secretase 1          9606       None  None
# 10615  ...    Homo sapiens  Beta-secretase 1          9606       None  None
# 10616  ...    Homo sapiens  Beta-secretase 1          9606       None  None
# 10617  ...    Homo sapiens  Beta-secretase 1          9606       None  None
# 10618  ...    Homo sapiens  Beta-secretase 1          9606       None  None
#
#        type units    uo_units upper_value   value
# 0      IC50    nM  UO_0000065        None   413.0
# 1      IC50    uM  UO_0000065        None   0.002
# 2      IC50    uM  UO_0000065        None    0.46
# 3      IC50    uM  UO_0000065        None     9.0
# 4      IC50    uM  UO_0000065        None     5.6
# ...     ...   ...         ...         ...     ...
# 10614  IC50    nM  UO_0000065        None   775.0
# 10615  IC50    nM  UO_0000065        None  1031.0
# 10616  IC50    nM  UO_0000065        None   828.0
# 10617  IC50    nM  UO_0000065        None    15.1
# 10618  IC50    nM  UO_0000065        None    15.4
#
# [10472 rows x 46 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 7353

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                              action_type activity_comment  \
# 0                                                   None             None
# 1                                                   None             None
# 2                                                   None             None
# 3                                                   None             None
# 4                                                   None             None
# ...                                                  ...              ...
# 10614  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 10615  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 10616  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 10617  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 10618  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#        activity_id                                activity_properties  \
# 0            78857                                                 []
# 1           391560                                                 []
# 2           391983                                                 []
# 3           395858                                                 []
# 4           395859                                                 []
# ...            ...                                                ...
# 10614     24890923  [{'comments': None, 'relation': '=', 'result_f...
# 10615     24890924  [{'comments': None, 'relation': '=', 'result_f...
# 10616     24890925  [{'comments': None, 'relation': '=', 'result_f...
# 10617     24963344                                                 []
# 10618     24963345                                                 []
#
#       assay_chembl_id                                  assay_description  \
# 0        CHEMBL653511  Inhibitory activity against Beta-secretase 1 w...
# 1        CHEMBL653332  Compound was tested for its inhibitory activit...
# 2        CHEMBL653512               Inhibition of human Beta-secretase 1
# 3        CHEMBL653512               Inhibition of human Beta-secretase 1
# 4        CHEMBL653512               Inhibition of human Beta-secretase 1
# ...               ...                                                ...
# 10614   CHEMBL5158468  Inhibition of BACE1 (unknown origin) using Mca...
# 10615   CHEMBL5158468  Inhibition of BACE1 (unknown origin) using Mca...
# 10616   CHEMBL5158468  Inhibition of BACE1 (unknown origin) using Mca...
# 10617   CHEMBL5216426  Inhibition of BACE1 (unknown origin) using A-b...
# 10618   CHEMBL5216426  Inhibition of BACE1 (unknown origin) using A-b...
#
#       assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0              B                    None                   None  BAO_0000190
# 1              B                    None                   None  BAO_0000190
# 2              B                    None                   None  BAO_0000190
# 3              B                    None                   None  BAO_0000190
# 4              B                    None                   None  BAO_0000190
# ...          ...                     ...                    ...          ...
# 10614          B                    None                   None  BAO_0000190
# 10615          B                    None                   None  BAO_0000190
# 10616          B                    None                   None  BAO_0000190
# 10617          B                    None                   None  BAO_0000190
# 10618          B                    None                   None  BAO_0000190
#
#        ... target_organism  target_pref_name target_tax_id text_value  toid  \
# 0      ...    Homo sapiens  Beta-secretase 1          9606       None  None
# 1      ...    Homo sapiens  Beta-secretase 1          9606       None  None
# 2      ...    Homo sapiens  Beta-secretase 1          9606       None  None
# 3      ...    Homo sapiens  Beta-secretase 1          9606       None  None
# 4      ...    Homo sapiens  Beta-secretase 1          9606       None  None
# ...    ...             ...               ...           ...        ...   ...
# 10614  ...    Homo sapiens  Beta-secretase 1          9606       None  None
# 10615  ...    Homo sapiens  Beta-secretase 1          9606       None  None
# 10616  ...    Homo sapiens  Beta-secretase 1          9606       None  None
# 10617  ...    Homo sapiens  Beta-secretase 1          9606       None  None
# 10618  ...    Homo sapiens  Beta-secretase 1          9606       None  None
#
#        type units    uo_units upper_value   value
# 0      IC50    nM  UO_0000065        None   413.0
# 1      IC50    uM  UO_0000065        None   0.002
# 2      IC50    uM  UO_0000065        None    0.46
# 3      IC50    uM  UO_0000065        None     9.0
# 4      IC50    uM  UO_0000065        None     5.6
# ...     ...   ...         ...         ...     ...
# 10614  IC50    nM  UO_0000065        None   775.0
# 10615  IC50    nM  UO_0000065        None  1031.0
# 10616  IC50    nM  UO_0000065        None   828.0
# 10617  IC50    nM  UO_0000065        None    15.1
# 10618  IC50    nM  UO_0000065        None    15.4
#
# [7353 rows x 46 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#       molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL406146  CC(C)C[C@H](NC(=O)[C@@H](NC(=O)[C@@H](N)CCC(=O...
# 1            CHEMBL78946  CC(C)C[C@H](NC(=O)[C@H](CC(N)=O)NC(=O)[C@@H](N...
# 2           CHEMBL324109  CCC(C)C[C@H](NC(=O)[C@H](CC(C)C)NC(C)=O)[C@@H]...
# 3           CHEMBL114147  CC(=O)NCC(=O)N[C@@H](Cc1ccccc1)[C@@H](O)CC(=O)...
# 4           CHEMBL419949  CC(=O)N[C@@H](Cc1ccccc1)C(=O)N[C@@H](Cc1ccccc1...
# ...                  ...                                                ...
# 10614      CHEMBL5192597  COC(=O)[C@@H]1CCCN1C(=O)[C@@H](Cc1ccc(O)cc1)N(...
# 10615      CHEMBL5184180  CC(C)C[C@H](NC(=O)C[C@H](O)[C@H](Cc1ccccc1)NC(...
# 10616      CHEMBL5184529  CC(C)C[C@H](NC(=O)C[C@H](O)[C@H](Cc1ccccc1)NC(...
# 10617      CHEMBL5220695      CC(C)(C)OC(=O)Nc1ccc(O)c(C(=O)NCCCN2CCCCC2)c1
# 10618      CHEMBL5219239       CC1CCCCN1CCCNC(=O)c1cc(NC(=O)OC(C)(C)C)ccc1O
#
#       standard_value
# 0              413.0
# 1                2.0
# 2              460.0
# 3             9000.0
# 4             5600.0
# ...              ...
# 10614          775.0
# 10615         1031.0
# 10616          828.0
# 10617           15.1
# 10618           15.4
#
# [7353 rows x 3 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('BACE_2_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 2000 nM will be considered to be **active** while those greater than 8000 nM will be considered to be **inactive**. As for those values in between 2,000 and 8,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('BACE_2_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='bioactivity_class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL406146  CC(C)C[C@H](NC(=O)[C@@H](NC(=O)[C@@H](N)CCC(=O...
# 1           CHEMBL78946  CC(C)C[C@H](NC(=O)[C@H](CC(N)=O)NC(=O)[C@@H](N...
# 2          CHEMBL324109  CCC(C)C[C@H](NC(=O)[C@H](CC(C)C)NC(C)=O)[C@@H]...
# 3          CHEMBL114147  CC(=O)NCC(=O)N[C@@H](Cc1ccccc1)[C@@H](O)CC(=O)...
# 4          CHEMBL419949  CC(=O)N[C@@H](Cc1ccccc1)C(=O)N[C@@H](Cc1ccccc1...
# ...                 ...                                                ...
# 7348      CHEMBL5192597  COC(=O)[C@@H]1CCCN1C(=O)[C@@H](Cc1ccc(O)cc1)N(...
# 7349      CHEMBL5184180  CC(C)C[C@H](NC(=O)C[C@H](O)[C@H](Cc1ccccc1)NC(...
# 7350      CHEMBL5184529  CC(C)C[C@H](NC(=O)C[C@H](O)[C@H](Cc1ccccc1)NC(...
# 7351      CHEMBL5220695      CC(C)(C)OC(=O)Nc1ccc(O)c(C(=O)NCCCN2CCCCC2)c1
# 7352      CHEMBL5219239       CC1CCCCN1CCCNC(=O)c1cc(NC(=O)OC(C)(C)C)ccc1O
#
#       standard_value bioactivity_class
# 0              413.0            active
# 1                2.0            active
# 2              460.0            active
# 3             9000.0      intermediate
# 4             5600.0      intermediate
# ...              ...               ...
# 7348           775.0            active
# 7349          1031.0      intermediate
# 7350           828.0            active
# 7351            15.1            active
# 7352            15.4            active
#
# [7353 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('BACE_03_bioactivity_data_curated.csv', index=False)

# %%
! zip BACE1.zip *.csv
# Out:
#   adding: BACE_03_bioactivity_data_curated.csv (deflated 85%)
#   adding: BACE_1_bioactivity_data_raw.csv (deflated 94%)
#   adding: BACE_2_bioactivity_data_preprocessed.csv (deflated 84%)

# %%
! ls -l
# Out:
# total 10888
# -rw-r--r-- 1 root root  701286 Jul 21 15:09 BACE_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root 9023088 Jul 21 15:09 BACE_1_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  777917 Jul 21 15:09 BACE1.zip
# -rw-r--r-- 1 root root  638859 Jul 21 15:09 BACE_2_bioactivity_data_preprocessed.csv
# drwxr-xr-x 1 root root    4096 Jul 18 13:43 sample_data
